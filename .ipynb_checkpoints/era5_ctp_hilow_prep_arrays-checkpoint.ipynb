# %%
import xarray as xr

import numpy as np

import scipy.stats as stats

import pandas as pd

from sklearn.cluster import KMeans

from sklearn.preprocessing import StandardScaler

import glob

import datetime

import matplotlib.pyplot as plt

import pickle

import cartopy.crs as ccrs

import cartopy.feature as cfeature

from scipy.stats import spearmanr

import seaborn as sns

import os

import matplotlib.colors as mcolors

from matplotlib.colors import TwoSlopeNorm

from sklearn.metrics import silhouette_score

from scipy.stats import pearsonr

from pathlib import Path

from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

import metpy.calc as mpcalc

from metpy.constants import Rd

from metpy.units import units

pd.options.mode.chained_assignment = None

# %%
import numpy as np

data1 = np.load(
    "/home/annierosen16/backup_data/backup_arrays_for_buoyancy_12lst_1979_2000.npz",
    mmap_mode="r"
)

data2 = np.load(
    "/home/annierosen16/backup_data/backup_arrays_for_buoyancy_12lst_2001_2025.npz",
    mmap_mode="r"
)

# These DO NOT load full arrays into RAM
p1_shape = data1["array1"].shape
p2_shape = data2["array1"].shape

print("p1 shape:", p1_shape)
print("p2 shape:", p2_shape)

# Combined pressure shape (without concatenating)
combined_shape = (
    p1_shape[0] + p2_shape[0],  # time dimension adds
    p1_shape[1],
    p1_shape[2],
    p1_shape[3],
)

print("Combined pressure shape:", combined_shape)
# Out:
# p1 shape: (3366, 201, 37, 41)
# p2 shape: (3825, 201, 37, 41)
# Combined pressure shape: (7191, 201, 37, 41)

# %% [markdown]
# ## preparing arrays for era5_compute_ctp_hilow.py script

# %%
data1 = np.load("/home/annierosen16/backup_data/backup_arrays_for_buoyancy_12lst_1979_2000.npz")

data2 = np.load("/home/annierosen16/backup_data/backup_arrays_for_buoyancy_12lst_2001_2025.npz")

# Pull arrays (same names in both)

p1 = data1["array1"]   # (time, z, lat, lon)

print("p1 loaded")

q1 = data1["array2"]

print("q1 loaded")

t1 = data1["array3"]

print("t1 loaded")

p2 = data2["array1"]

print("p2 loaded")

q2 = data2["array2"]

print("q2 loaded")

t2 = data2["array3"]

print("t2 loaded")

# Concatenate along time

pressure = np.concatenate([p1, p2], axis=0)

print("pressure combined")

specific_humidity = np.concatenate([q1, q2], axis=0)

print("specific humidity combined")

temperature = np.concatenate([t1, t2], axis=0) + 273.15  # convert C -> K after concat (or before, same result)

print("temperature combined")

print("pressure:", pressure.shape)

print("q:", specific_humidity.shape)

print("T (K):", temperature.shape)

# Altitude grid (0–4000 m every 20 m)

altitude = np.arange(0, 4000 + 20, 20)

print("altitude:", altitude.shape)
# Out:
# p1 loaded
# q1 loaded
# t1 loaded
# p2 loaded
# q2 loaded

# %%
# # these are all interpolated to every 20 m

# pressure = data['array1'] # Shape: (time, pressure_level, lat, lon)

# print("p loaded")

# specific_humidity = data['array2'] # Shape: (time, pressure_level, lat, lon)

# print("q loaded")

# temperature = data['array3'] # Shape: (time, pressure_level, lat, lon) in Celsius

# temperature = temperature + 273.15 # converting to Kelvin

# print("t loaded")

# altitude = np.arange(0, 4000 + 20, 20)

# # calculating dewpoint from specific humidity 

# # temp conversion to kelvin necessary for dewpoint calculation 

# temperature = (temperature + 273.15) * units.K

# print("t complete")

# pressure = pressure * units.hPa  

# print("p complete")

# humidity = q * units('g/kg')

# print("q complete")

# dewpoint = mpcalc.dewpoint_from_specific_humidity(pressure, temperature, humidity)

# print("dewpoint complete")

# %%
nt, nz, ny, nx = pressure.shape

# Use float32 to reduce memory

p = pressure.astype(np.float32)      # hPa

print("p converted to float32")

T = temperature.astype(np.float32)   # K

print("T converted to float32")

q = specific_humidity.astype(np.float32) # g/kg

print("q converted to float32")

# Output dewpoint in Celsius

td_out = np.memmap(
    
    "/home/annierosen16/backup_data/dewpoint_for_ctp_hilow_1979_2025.dat",
    
    dtype="float32",
    
    mode="w+",
    
    shape=(nt, nz, ny, nx)
)

print("td_out created")

chunk = 10  # adjust upward if stable

for t0 in range(0, nt, chunk):
    
    t1 = min(t0 + chunk, nt)
    
    print(f"MetPy dewpoint: {t0}:{t1}")

    # Attach units ONLY to the chunk
    
    p_chunk = p[t0:t1] * units.hPa
    
    T_chunk = T[t0:t1] * units.K
    
    q_chunk = q[t0:t1] * units("g/kg")

    # MetPy returns dewpoint in temperature units (°C by default)
    
    td_chunk = mpcalc.dewpoint_from_specific_humidity(
        
        p_chunk, T_chunk, q_chunk)

    # Store magnitudes in °C
    
    td_out[t0:t1] = td_chunk.magnitude.astype(np.float32)

td_out.flush()

print("done")
# Out:
# p converted to float32
# T converted to float32
# q converted to float32
# td_out created
# MetPy dewpoint: 0:10
# MetPy dewpoint: 10:20
# MetPy dewpoint: 20:30
# MetPy dewpoint: 30:40
# MetPy dewpoint: 40:50
# MetPy dewpoint: 50:60
# MetPy dewpoint: 60:70
# MetPy dewpoint: 70:80
# MetPy dewpoint: 80:90
# MetPy dewpoint: 90:100
# MetPy dewpoint: 100:110
# MetPy dewpoint: 110:120
# MetPy dewpoint: 120:130
# MetPy dewpoint: 130:140
# MetPy dewpoint: 140:150
# MetPy dewpoint: 150:160
# MetPy dewpoint: 160:170
# MetPy dewpoint: 170:180
# MetPy dewpoint: 180:190
# MetPy dewpoint: 190:200
# MetPy dewpoint: 200:210
# MetPy dewpoint: 210:220
# MetPy dewpoint: 220:230
# MetPy dewpoint: 230:240
# MetPy dewpoint: 240:250
# MetPy dewpoint: 250:260
# MetPy dewpoint: 260:270
# MetPy dewpoint: 270:280
# MetPy dewpoint: 280:290
# MetPy dewpoint: 290:300
# MetPy dewpoint: 300:310
# MetPy dewpoint: 310:320
# MetPy dewpoint: 320:330
# MetPy dewpoint: 330:340
# MetPy dewpoint: 340:350
# MetPy dewpoint: 350:360
# MetPy dewpoint: 360:370
# MetPy dewpoint: 370:380
# MetPy dewpoint: 380:390
# MetPy dewpoint: 390:400
# MetPy dewpoint: 400:410
# MetPy dewpoint: 410:420
# MetPy dewpoint: 420:430
# MetPy dewpoint: 430:440
# MetPy dewpoint: 440:450
# MetPy dewpoint: 450:460
# MetPy dewpoint: 460:470
# MetPy dewpoint: 470:480
# MetPy dewpoint: 480:490
# MetPy dewpoint: 490:500
# MetPy dewpoint: 500:510
# MetPy dewpoint: 510:520
# MetPy dewpoint: 520:530
# MetPy dewpoint: 530:540
# MetPy dewpoint: 540:550
# MetPy dewpoint: 550:560
# MetPy dewpoint: 560:570
# MetPy dewpoint: 570:580
# MetPy dewpoint: 580:590
# MetPy dewpoint: 590:600
# MetPy dewpoint: 600:610
# MetPy dewpoint: 610:620
# MetPy dewpoint: 620:630
# MetPy dewpoint: 630:640
# MetPy dewpoint: 640:650
# MetPy dewpoint: 650:660
# MetPy dewpoint: 660:670
# MetPy dewpoint: 670:680
# MetPy dewpoint: 680:690
# MetPy dewpoint: 690:700
# MetPy dewpoint: 700:710
# MetPy dewpoint: 710:720
# MetPy dewpoint: 720:730
# MetPy dewpoint: 730:740
# MetPy dewpoint: 740:750
# MetPy dewpoint: 750:760
# MetPy dewpoint: 760:770
# MetPy dewpoint: 770:780
# MetPy dewpoint: 780:790
# MetPy dewpoint: 790:800
# MetPy dewpoint: 800:810
# MetPy dewpoint: 810:820
# MetPy dewpoint: 820:830
# MetPy dewpoint: 830:840
# MetPy dewpoint: 840:850
# MetPy dewpoint: 850:860
# MetPy dewpoint: 860:870
# MetPy dewpoint: 870:880
# MetPy dewpoint: 880:890
# MetPy dewpoint: 890:900
# MetPy dewpoint: 900:910
# MetPy dewpoint: 910:920
# MetPy dewpoint: 920:930
# MetPy dewpoint: 930:940
# MetPy dewpoint: 940:950
# MetPy dewpoint: 950:960
# MetPy dewpoint: 960:970
# MetPy dewpoint: 970:980
# MetPy dewpoint: 980:990
# MetPy dewpoint: 990:1000
# MetPy dewpoint: 1000:1010
# MetPy dewpoint: 1010:1020
# MetPy dewpoint: 1020:1030
# MetPy dewpoint: 1030:1040
# MetPy dewpoint: 1040:1050
# MetPy dewpoint: 1050:1060
# MetPy dewpoint: 1060:1070
# MetPy dewpoint: 1070:1080
# MetPy dewpoint: 1080:1090
# MetPy dewpoint: 1090:1100
# MetPy dewpoint: 1100:1110
# MetPy dewpoint: 1110:1120
# MetPy dewpoint: 1120:1130
# MetPy dewpoint: 1130:1140
# MetPy dewpoint: 1140:1150
# MetPy dewpoint: 1150:1160
# MetPy dewpoint: 1160:1170
# MetPy dewpoint: 1170:1180
# MetPy dewpoint: 1180:1190
# MetPy dewpoint: 1190:1200
# MetPy dewpoint: 1200:1210
# MetPy dewpoint: 1210:1220
# MetPy dewpoint: 1220:1230
# MetPy dewpoint: 1230:1240
# MetPy dewpoint: 1240:1250
# MetPy dewpoint: 1250:1260
# MetPy dewpoint: 1260:1270
# MetPy dewpoint: 1270:1280
# MetPy dewpoint: 1280:1290
# MetPy dewpoint: 1290:1300
# MetPy dewpoint: 1300:1310
# MetPy dewpoint: 1310:1320
# MetPy dewpoint: 1320:1330
# MetPy dewpoint: 1330:1340
# MetPy dewpoint: 1340:1350
# MetPy dewpoint: 1350:1360
# MetPy dewpoint: 1360:1370
# MetPy dewpoint: 1370:1380
# MetPy dewpoint: 1380:1390
# MetPy dewpoint: 1390:1400
# MetPy dewpoint: 1400:1410
# MetPy dewpoint: 1410:1420
# MetPy dewpoint: 1420:1430
# MetPy dewpoint: 1430:1440
# MetPy dewpoint: 1440:1450
# MetPy dewpoint: 1450:1460
# MetPy dewpoint: 1460:1470
# MetPy dewpoint: 1470:1480
# MetPy dewpoint: 1480:1490
# MetPy dewpoint: 1490:1500
# MetPy dewpoint: 1500:1510
# MetPy dewpoint: 1510:1520
# MetPy dewpoint: 1520:1530
# MetPy dewpoint: 1530:1540
# MetPy dewpoint: 1540:1550
# MetPy dewpoint: 1550:1560
# MetPy dewpoint: 1560:1570
# MetPy dewpoint: 1570:1580
# MetPy dewpoint: 1580:1590
# MetPy dewpoint: 1590:1600
# MetPy dewpoint: 1600:1610
# MetPy dewpoint: 1610:1620
# MetPy dewpoint: 1620:1630
# MetPy dewpoint: 1630:1640
# MetPy dewpoint: 1640:1650
# MetPy dewpoint: 1650:1660
# MetPy dewpoint: 1660:1670
# MetPy dewpoint: 1670:1680
# MetPy dewpoint: 1680:1690
# MetPy dewpoint: 1690:1700
# MetPy dewpoint: 1700:1710
# MetPy dewpoint: 1710:1720
# MetPy dewpoint: 1720:1730
# MetPy dewpoint: 1730:1740
# MetPy dewpoint: 1740:1750
# MetPy dewpoint: 1750:1760
# MetPy dewpoint: 1760:1770
# MetPy dewpoint: 1770:1780
# MetPy dewpoint: 1780:1790
# MetPy dewpoint: 1790:1800
# MetPy dewpoint: 1800:1810
# MetPy dewpoint: 1810:1820
# MetPy dewpoint: 1820:1830
# MetPy dewpoint: 1830:1840
# MetPy dewpoint: 1840:1850
# MetPy dewpoint: 1850:1860
# MetPy dewpoint: 1860:1870
# MetPy dewpoint: 1870:1880
# MetPy dewpoint: 1880:1890
# MetPy dewpoint: 1890:1900
# MetPy dewpoint: 1900:1910
# MetPy dewpoint: 1910:1920
# MetPy dewpoint: 1920:1930
# MetPy dewpoint: 1930:1940
# MetPy dewpoint: 1940:1950
# MetPy dewpoint: 1950:1960
# MetPy dewpoint: 1960:1970
# MetPy dewpoint: 1970:1980
# MetPy dewpoint: 1980:1990
# MetPy dewpoint: 1990:2000
# MetPy dewpoint: 2000:2010
# MetPy dewpoint: 2010:2020
# MetPy dewpoint: 2020:2030
# MetPy dewpoint: 2030:2040
# MetPy dewpoint: 2040:2050
# MetPy dewpoint: 2050:2060
# MetPy dewpoint: 2060:2070
# MetPy dewpoint: 2070:2080
# MetPy dewpoint: 2080:2090
# MetPy dewpoint: 2090:2100
# MetPy dewpoint: 2100:2110
# MetPy dewpoint: 2110:2120
# MetPy dewpoint: 2120:2130
# MetPy dewpoint: 2130:2140
# MetPy dewpoint: 2140:2150
# MetPy dewpoint: 2150:2160
# MetPy dewpoint: 2160:2170
# MetPy dewpoint: 2170:2180
# MetPy dewpoint: 2180:2190
# MetPy dewpoint: 2190:2200
# MetPy dewpoint: 2200:2210
# MetPy dewpoint: 2210:2220
# MetPy dewpoint: 2220:2230
# MetPy dewpoint: 2230:2240
# MetPy dewpoint: 2240:2250
# MetPy dewpoint: 2250:2260
# MetPy dewpoint: 2260:2270
# MetPy dewpoint: 2270:2280
# MetPy dewpoint: 2280:2290
# MetPy dewpoint: 2290:2300
# MetPy dewpoint: 2300:2310
# MetPy dewpoint: 2310:2320
# MetPy dewpoint: 2320:2330
# MetPy dewpoint: 2330:2340
# MetPy dewpoint: 2340:2350
# MetPy dewpoint: 2350:2360
# MetPy dewpoint: 2360:2370
# MetPy dewpoint: 2370:2380
# MetPy dewpoint: 2380:2390
# MetPy dewpoint: 2390:2400
# MetPy dewpoint: 2400:2410
# MetPy dewpoint: 2410:2420
# MetPy dewpoint: 2420:2430
# MetPy dewpoint: 2430:2440
# MetPy dewpoint: 2440:2450
# MetPy dewpoint: 2450:2460
# MetPy dewpoint: 2460:2470
# MetPy dewpoint: 2470:2480
# MetPy dewpoint: 2480:2490
# MetPy dewpoint: 2490:2500
# MetPy dewpoint: 2500:2510
# MetPy dewpoint: 2510:2520
# MetPy dewpoint: 2520:2530
# MetPy dewpoint: 2530:2540
# MetPy dewpoint: 2540:2550
# MetPy dewpoint: 2550:2560
# MetPy dewpoint: 2560:2570
# MetPy dewpoint: 2570:2580
# MetPy dewpoint: 2580:2590
# MetPy dewpoint: 2590:2600
# MetPy dewpoint: 2600:2610
# MetPy dewpoint: 2610:2620
# MetPy dewpoint: 2620:2630
# MetPy dewpoint: 2630:2640
# MetPy dewpoint: 2640:2650
# MetPy dewpoint: 2650:2660
# MetPy dewpoint: 2660:2670
# MetPy dewpoint: 2670:2680
# MetPy dewpoint: 2680:2690
# MetPy dewpoint: 2690:2700
# MetPy dewpoint: 2700:2710
# MetPy dewpoint: 2710:2720
# MetPy dewpoint: 2720:2730
# MetPy dewpoint: 2730:2740
# MetPy dewpoint: 2740:2750
# MetPy dewpoint: 2750:2760
# MetPy dewpoint: 2760:2770
# MetPy dewpoint: 2770:2780
# MetPy dewpoint: 2780:2790
# MetPy dewpoint: 2790:2800
# MetPy dewpoint: 2800:2810
# MetPy dewpoint: 2810:2820
# MetPy dewpoint: 2820:2830
# MetPy dewpoint: 2830:2840
# MetPy dewpoint: 2840:2850
# MetPy dewpoint: 2850:2860
# MetPy dewpoint: 2860:2870
# MetPy dewpoint: 2870:2880
# MetPy dewpoint: 2880:2890
# MetPy dewpoint: 2890:2900
# MetPy dewpoint: 2900:2910
# MetPy dewpoint: 2910:2920
# MetPy dewpoint: 2920:2930
# MetPy dewpoint: 2930:2940
# MetPy dewpoint: 2940:2950
# MetPy dewpoint: 2950:2960
# MetPy dewpoint: 2960:2970
# MetPy dewpoint: 2970:2980
# MetPy dewpoint: 2980:2990
# MetPy dewpoint: 2990:3000
# MetPy dewpoint: 3000:3010
# MetPy dewpoint: 3010:3020
# MetPy dewpoint: 3020:3030
# MetPy dewpoint: 3030:3040
# MetPy dewpoint: 3040:3050
# MetPy dewpoint: 3050:3060
# MetPy dewpoint: 3060:3070
# MetPy dewpoint: 3070:3080
# MetPy dewpoint: 3080:3090
# MetPy dewpoint: 3090:3100
# MetPy dewpoint: 3100:3110
# MetPy dewpoint: 3110:3120
# MetPy dewpoint: 3120:3130
# MetPy dewpoint: 3130:3140
# MetPy dewpoint: 3140:3150
# MetPy dewpoint: 3150:3160
# MetPy dewpoint: 3160:3170
# MetPy dewpoint: 3170:3180
# MetPy dewpoint: 3180:3190
# MetPy dewpoint: 3190:3200
# MetPy dewpoint: 3200:3210
# MetPy dewpoint: 3210:3220
# MetPy dewpoint: 3220:3230
# MetPy dewpoint: 3230:3240
# MetPy dewpoint: 3240:3250
# MetPy dewpoint: 3250:3260
# MetPy dewpoint: 3260:3270
# MetPy dewpoint: 3270:3280
# MetPy dewpoint: 3280:3290
# MetPy dewpoint: 3290:3300
# MetPy dewpoint: 3300:3310
# MetPy dewpoint: 3310:3320
# MetPy dewpoint: 3320:3330
# MetPy dewpoint: 3330:3340
# MetPy dewpoint: 3340:3350
# MetPy dewpoint: 3350:3360
# MetPy dewpoint: 3360:3370
# MetPy dewpoint: 3370:3380
# MetPy dewpoint: 3380:3390
# MetPy dewpoint: 3390:3400
# MetPy dewpoint: 3400:3410
# MetPy dewpoint: 3410:3420
# MetPy dewpoint: 3420:3430
# MetPy dewpoint: 3430:3440
# MetPy dewpoint: 3440:3450
# MetPy dewpoint: 3450:3460
# MetPy dewpoint: 3460:3470
# MetPy dewpoint: 3470:3480
# MetPy dewpoint: 3480:3490
# MetPy dewpoint: 3490:3500
# MetPy dewpoint: 3500:3510
# MetPy dewpoint: 3510:3520
# MetPy dewpoint: 3520:3530
# MetPy dewpoint: 3530:3540
# MetPy dewpoint: 3540:3550
# MetPy dewpoint: 3550:3560
# MetPy dewpoint: 3560:3570
# MetPy dewpoint: 3570:3580
# MetPy dewpoint: 3580:3590
# MetPy dewpoint: 3590:3600
# MetPy dewpoint: 3600:3610
# MetPy dewpoint: 3610:3620
# MetPy dewpoint: 3620:3630
# MetPy dewpoint: 3630:3640
# MetPy dewpoint: 3640:3650
# MetPy dewpoint: 3650:3660
# MetPy dewpoint: 3660:3670
# MetPy dewpoint: 3670:3680
# MetPy dewpoint: 3680:3690
# MetPy dewpoint: 3690:3700
# MetPy dewpoint: 3700:3710
# MetPy dewpoint: 3710:3720
# MetPy dewpoint: 3720:3730
# MetPy dewpoint: 3730:3740
# MetPy dewpoint: 3740:3750
# MetPy dewpoint: 3750:3760
# MetPy dewpoint: 3760:3770
# MetPy dewpoint: 3770:3780
# MetPy dewpoint: 3780:3790
# MetPy dewpoint: 3790:3800
# MetPy dewpoint: 3800:3810
# MetPy dewpoint: 3810:3820
# MetPy dewpoint: 3820:3830
# MetPy dewpoint: 3830:3840
# MetPy dewpoint: 3840:3850
# MetPy dewpoint: 3850:3860
# MetPy dewpoint: 3860:3870
# MetPy dewpoint: 3870:3880
# MetPy dewpoint: 3880:3890
# MetPy dewpoint: 3890:3900
# MetPy dewpoint: 3900:3910
# MetPy dewpoint: 3910:3920
# MetPy dewpoint: 3920:3930
# MetPy dewpoint: 3930:3940
# MetPy dewpoint: 3940:3950
# MetPy dewpoint: 3950:3960
# MetPy dewpoint: 3960:3970
# MetPy dewpoint: 3970:3980
# MetPy dewpoint: 3980:3990
# MetPy dewpoint: 3990:4000
# MetPy dewpoint: 4000:4010
# MetPy dewpoint: 4010:4020
# MetPy dewpoint: 4020:4030
# MetPy dewpoint: 4030:4040
# MetPy dewpoint: 4040:4050
# MetPy dewpoint: 4050:4060
# MetPy dewpoint: 4060:4070
# MetPy dewpoint: 4070:4080
# MetPy dewpoint: 4080:4090
# MetPy dewpoint: 4090:4100
# MetPy dewpoint: 4100:4110
# MetPy dewpoint: 4110:4120
# MetPy dewpoint: 4120:4130
# MetPy dewpoint: 4130:4140
# MetPy dewpoint: 4140:4150
# MetPy dewpoint: 4150:4160
# MetPy dewpoint: 4160:4170
# MetPy dewpoint: 4170:4180
# MetPy dewpoint: 4180:4190
# MetPy dewpoint: 4190:4200
# MetPy dewpoint: 4200:4210
# MetPy dewpoint: 4210:4220
# MetPy dewpoint: 4220:4230
# MetPy dewpoint: 4230:4240
# MetPy dewpoint: 4240:4250
# MetPy dewpoint: 4250:4260
# MetPy dewpoint: 4260:4270
# MetPy dewpoint: 4270:4280
# MetPy dewpoint: 4280:4290
# MetPy dewpoint: 4290:4300
# MetPy dewpoint: 4300:4310
# MetPy dewpoint: 4310:4320
# MetPy dewpoint: 4320:4330
# MetPy dewpoint: 4330:4340
# MetPy dewpoint: 4340:4350
# MetPy dewpoint: 4350:4360
# MetPy dewpoint: 4360:4370
# MetPy dewpoint: 4370:4380
# MetPy dewpoint: 4380:4390
# MetPy dewpoint: 4390:4400
# MetPy dewpoint: 4400:4410
# MetPy dewpoint: 4410:4420
# MetPy dewpoint: 4420:4430
# MetPy dewpoint: 4430:4440
# MetPy dewpoint: 4440:4450
# MetPy dewpoint: 4450:4460
# MetPy dewpoint: 4460:4470
# MetPy dewpoint: 4470:4480
# MetPy dewpoint: 4480:4490
# MetPy dewpoint: 4490:4500
# MetPy dewpoint: 4500:4510
# MetPy dewpoint: 4510:4520
# MetPy dewpoint: 4520:4530
# MetPy dewpoint: 4530:4540
# MetPy dewpoint: 4540:4550
# MetPy dewpoint: 4550:4560
# MetPy dewpoint: 4560:4570
# MetPy dewpoint: 4570:4580
# MetPy dewpoint: 4580:4590
# MetPy dewpoint: 4590:4600
# MetPy dewpoint: 4600:4610
# MetPy dewpoint: 4610:4620
# MetPy dewpoint: 4620:4630
# MetPy dewpoint: 4630:4640
# MetPy dewpoint: 4640:4650
# MetPy dewpoint: 4650:4660
# MetPy dewpoint: 4660:4670
# MetPy dewpoint: 4670:4680
# MetPy dewpoint: 4680:4690
# MetPy dewpoint: 4690:4700
# MetPy dewpoint: 4700:4710
# MetPy dewpoint: 4710:4720
# MetPy dewpoint: 4720:4730
# MetPy dewpoint: 4730:4740
# MetPy dewpoint: 4740:4750
# MetPy dewpoint: 4750:4760
# MetPy dewpoint: 4760:4770
# MetPy dewpoint: 4770:4780
# MetPy dewpoint: 4780:4790
# MetPy dewpoint: 4790:4800
# MetPy dewpoint: 4800:4810
# MetPy dewpoint: 4810:4820
# MetPy dewpoint: 4820:4830
# MetPy dewpoint: 4830:4840
# MetPy dewpoint: 4840:4850
# MetPy dewpoint: 4850:4860
# MetPy dewpoint: 4860:4870
# MetPy dewpoint: 4870:4880
# MetPy dewpoint: 4880:4890
# MetPy dewpoint: 4890:4900
# MetPy dewpoint: 4900:4910
# MetPy dewpoint: 4910:4920
# MetPy dewpoint: 4920:4930
# MetPy dewpoint: 4930:4940
# MetPy dewpoint: 4940:4950
# MetPy dewpoint: 4950:4960
# MetPy dewpoint: 4960:4970
# MetPy dewpoint: 4970:4980
# MetPy dewpoint: 4980:4990
# MetPy dewpoint: 4990:5000
# MetPy dewpoint: 5000:5010
# MetPy dewpoint: 5010:5020
# MetPy dewpoint: 5020:5030
# MetPy dewpoint: 5030:5040
# MetPy dewpoint: 5040:5050
# MetPy dewpoint: 5050:5060
# MetPy dewpoint: 5060:5070
# MetPy dewpoint: 5070:5080
# MetPy dewpoint: 5080:5090
# MetPy dewpoint: 5090:5100
# MetPy dewpoint: 5100:5110
# MetPy dewpoint: 5110:5120
# MetPy dewpoint: 5120:5130
# MetPy dewpoint: 5130:5140
# MetPy dewpoint: 5140:5150
# MetPy dewpoint: 5150:5160
# MetPy dewpoint: 5160:5170
# MetPy dewpoint: 5170:5180
# MetPy dewpoint: 5180:5190
# MetPy dewpoint: 5190:5200
# MetPy dewpoint: 5200:5210
# MetPy dewpoint: 5210:5220
# MetPy dewpoint: 5220:5230
# MetPy dewpoint: 5230:5240
# MetPy dewpoint: 5240:5250
# MetPy dewpoint: 5250:5260
# MetPy dewpoint: 5260:5270
# MetPy dewpoint: 5270:5280
# MetPy dewpoint: 5280:5290
# MetPy dewpoint: 5290:5300
# MetPy dewpoint: 5300:5310
# MetPy dewpoint: 5310:5320
# MetPy dewpoint: 5320:5330
# MetPy dewpoint: 5330:5340
# MetPy dewpoint: 5340:5350
# MetPy dewpoint: 5350:5360
# MetPy dewpoint: 5360:5370
# MetPy dewpoint: 5370:5380
# MetPy dewpoint: 5380:5390
# MetPy dewpoint: 5390:5400
# MetPy dewpoint: 5400:5410
# MetPy dewpoint: 5410:5420
# MetPy dewpoint: 5420:5430
# MetPy dewpoint: 5430:5440
# MetPy dewpoint: 5440:5450
# MetPy dewpoint: 5450:5460
# MetPy dewpoint: 5460:5470
# MetPy dewpoint: 5470:5480
# MetPy dewpoint: 5480:5490
# MetPy dewpoint: 5490:5500
# MetPy dewpoint: 5500:5510
# MetPy dewpoint: 5510:5520
# MetPy dewpoint: 5520:5530
# MetPy dewpoint: 5530:5540
# MetPy dewpoint: 5540:5550
# MetPy dewpoint: 5550:5560
# MetPy dewpoint: 5560:5570
# MetPy dewpoint: 5570:5580
# MetPy dewpoint: 5580:5590
# MetPy dewpoint: 5590:5600
# MetPy dewpoint: 5600:5610
# MetPy dewpoint: 5610:5620
# MetPy dewpoint: 5620:5630
# MetPy dewpoint: 5630:5640
# MetPy dewpoint: 5640:5650
# MetPy dewpoint: 5650:5660
# MetPy dewpoint: 5660:5670
# MetPy dewpoint: 5670:5680
# MetPy dewpoint: 5680:5690
# MetPy dewpoint: 5690:5700
# MetPy dewpoint: 5700:5710
# MetPy dewpoint: 5710:5720
# MetPy dewpoint: 5720:5730
# MetPy dewpoint: 5730:5740
# MetPy dewpoint: 5740:5750
# MetPy dewpoint: 5750:5760
# MetPy dewpoint: 5760:5770
# MetPy dewpoint: 5770:5780
# MetPy dewpoint: 5780:5790
# MetPy dewpoint: 5790:5800
# MetPy dewpoint: 5800:5810
# MetPy dewpoint: 5810:5820
# MetPy dewpoint: 5820:5830
# MetPy dewpoint: 5830:5840
# MetPy dewpoint: 5840:5850
# MetPy dewpoint: 5850:5860
# MetPy dewpoint: 5860:5870
# MetPy dewpoint: 5870:5880
# MetPy dewpoint: 5880:5890
# MetPy dewpoint: 5890:5900
# MetPy dewpoint: 5900:5910
# MetPy dewpoint: 5910:5920
# MetPy dewpoint: 5920:5930
# MetPy dewpoint: 5930:5940
# MetPy dewpoint: 5940:5950
# MetPy dewpoint: 5950:5960
# MetPy dewpoint: 5960:5970
# MetPy dewpoint: 5970:5980
# MetPy dewpoint: 5980:5990
# MetPy dewpoint: 5990:6000
# MetPy dewpoint: 6000:6010
# MetPy dewpoint: 6010:6020
# MetPy dewpoint: 6020:6030
# MetPy dewpoint: 6030:6040
# MetPy dewpoint: 6040:6050
# MetPy dewpoint: 6050:6060
# MetPy dewpoint: 6060:6070
# MetPy dewpoint: 6070:6080
# MetPy dewpoint: 6080:6090
# MetPy dewpoint: 6090:6100
# MetPy dewpoint: 6100:6110
# MetPy dewpoint: 6110:6120
# MetPy dewpoint: 6120:6130
# MetPy dewpoint: 6130:6140
# MetPy dewpoint: 6140:6150
# MetPy dewpoint: 6150:6160
# MetPy dewpoint: 6160:6170
# MetPy dewpoint: 6170:6180
# MetPy dewpoint: 6180:6190
# MetPy dewpoint: 6190:6200
# MetPy dewpoint: 6200:6210
# MetPy dewpoint: 6210:6220
# MetPy dewpoint: 6220:6230
# MetPy dewpoint: 6230:6240
# MetPy dewpoint: 6240:6250
# MetPy dewpoint: 6250:6260
# MetPy dewpoint: 6260:6270
# MetPy dewpoint: 6270:6280
# MetPy dewpoint: 6280:6290
# MetPy dewpoint: 6290:6300
# MetPy dewpoint: 6300:6310
# MetPy dewpoint: 6310:6320
# MetPy dewpoint: 6320:6330
# MetPy dewpoint: 6330:6340
# MetPy dewpoint: 6340:6350
# MetPy dewpoint: 6350:6360
# MetPy dewpoint: 6360:6370
# MetPy dewpoint: 6370:6380
# MetPy dewpoint: 6380:6390
# MetPy dewpoint: 6390:6400
# MetPy dewpoint: 6400:6410
# MetPy dewpoint: 6410:6420
# MetPy dewpoint: 6420:6430
# MetPy dewpoint: 6430:6440
# MetPy dewpoint: 6440:6450
# MetPy dewpoint: 6450:6460
# MetPy dewpoint: 6460:6470
# MetPy dewpoint: 6470:6480
# MetPy dewpoint: 6480:6490
# MetPy dewpoint: 6490:6500
# MetPy dewpoint: 6500:6510
# MetPy dewpoint: 6510:6520
# MetPy dewpoint: 6520:6530
# MetPy dewpoint: 6530:6540
# MetPy dewpoint: 6540:6550
# MetPy dewpoint: 6550:6560
# MetPy dewpoint: 6560:6570
# MetPy dewpoint: 6570:6580
# MetPy dewpoint: 6580:6590
# MetPy dewpoint: 6590:6600
# MetPy dewpoint: 6600:6610
# MetPy dewpoint: 6610:6620
# MetPy dewpoint: 6620:6630
# MetPy dewpoint: 6630:6640
# MetPy dewpoint: 6640:6650
# MetPy dewpoint: 6650:6660
# MetPy dewpoint: 6660:6670
# MetPy dewpoint: 6670:6680
# MetPy dewpoint: 6680:6690
# MetPy dewpoint: 6690:6700
# MetPy dewpoint: 6700:6710
# MetPy dewpoint: 6710:6720
# MetPy dewpoint: 6720:6730
# MetPy dewpoint: 6730:6740
# MetPy dewpoint: 6740:6750
# MetPy dewpoint: 6750:6760
# MetPy dewpoint: 6760:6770
# MetPy dewpoint: 6770:6780
# MetPy dewpoint: 6780:6790
# MetPy dewpoint: 6790:6800
# MetPy dewpoint: 6800:6810
# MetPy dewpoint: 6810:6820
# MetPy dewpoint: 6820:6830
# MetPy dewpoint: 6830:6840
# MetPy dewpoint: 6840:6850
# MetPy dewpoint: 6850:6860
# MetPy dewpoint: 6860:6870
# MetPy dewpoint: 6870:6880
# MetPy dewpoint: 6880:6890
# MetPy dewpoint: 6890:6900
# MetPy dewpoint: 6900:6910
# MetPy dewpoint: 6910:6920
# MetPy dewpoint: 6920:6930
# MetPy dewpoint: 6930:6940
# MetPy dewpoint: 6940:6950
# MetPy dewpoint: 6950:6960
# MetPy dewpoint: 6960:6970
# MetPy dewpoint: 6970:6980
# MetPy dewpoint: 6980:6990
# MetPy dewpoint: 6990:7000
# MetPy dewpoint: 7000:7010
# MetPy dewpoint: 7010:7020
# MetPy dewpoint: 7020:7030
# MetPy dewpoint: 7030:7040
# MetPy dewpoint: 7040:7050
# MetPy dewpoint: 7050:7060
# MetPy dewpoint: 7060:7070
# MetPy dewpoint: 7070:7080
# MetPy dewpoint: 7080:7090
# MetPy dewpoint: 7090:7100
# MetPy dewpoint: 7100:7110
# MetPy dewpoint: 7110:7120
# MetPy dewpoint: 7120:7130
# MetPy dewpoint: 7130:7140
# MetPy dewpoint: 7140:7150
# MetPy dewpoint: 7150:7160
# MetPy dewpoint: 7160:7170
# MetPy dewpoint: 7170:7180
# MetPy dewpoint: 7180:7190
# MetPy dewpoint: 7190:7191
# done

# %%
# # -------------------------------------------------
# # 1) Load pressure, temperature, humidity from NPZ
# # -------------------------------------------------
# npz_path = "/home/annierosen16/backup_data/backup_arrays_for_buoyancy_12lst_2001_2025.npz"

# data = np.load(npz_path)

# print("npz file loaded")

# # Arrays interpolated every 20 m AGL

# pressure = data["array1"]        # hPa, shape (time, level, lat, lon)

# # Altitude grid (AGL)
# altitude = np.arange(0, 4000 + 20, 20) * units.meter

# print("units attached")

# -------------------------------------------------
# 2) Load dewpoint from memmap (.dat)
# -------------------------------------------------

dat_path = "/home/annierosen16/backup_data/dewpoint_for_ctp_hilow_1979_2025.dat"

# Shape MUST match pressure

td = np.memmap(
    
    dat_path,
    
    dtype="float32",
    
    mode="r",
    
    shape=combined_shape
)

# Attach units (°C)

dewpoint79 = td * units.degC

print("dewpoint loaded")

print("Td range (°C):", np.nanmin(dewpoint79.magnitude), np.nanmax(dewpoint79.magnitude))
# Out:
# dewpoint loaded
# Td range (°C): -106.492676 28.398773

# %%
dat_path = "/home/annierosen16/backup_data/dewpoint_for_ctp_hilow_2001_2025.dat"

# Shape MUST match pressure

td = np.memmap(
    
    dat_path,
    
    dtype="float32",
    
    mode="r",
    
    shape=p2_shape
)

# Attach units (°C)

dewpoint01 = td * units.degC

print("dewpoint loaded")

print("Td range (°C):", np.nanmin(dewpoint01.magnitude), np.nanmax(dewpoint01.magnitude))
# Out:
# dewpoint loaded
# Td range (°C): -106.492676 28.398773

# %%
# # temp conversion back to deg C necessary for cal_ctp_hi 

# temperature = temperature.magnitude

# temperature = (temperature - 273.15) * units.degC

# %%
# # Remove the units (store only the raw values)

# temperature_data = temperature.magnitude

# dewpoint_data = dewpoint.magnitude

# pressure_data = pressure.magnitude

# altitude_data = altitude  

# # Create the directory if it doesn't exist

# backup_data_dir = os.path.expanduser('~/backup_data')

# os.makedirs(backup_data_dir, exist_ok=True)

# # Define the file path

# file_path = os.path.join(backup_data_dir, 'ctp_hilow_input_arrays_2001_2025.npz')

# # Save the arrays into the .npz file

# np.savez(file_path, temperature=temperature_data, dewpoint=dewpoint_data, pressure=pressure_data, altitude=altitude_data)

# print(f"Data saved successfully to {file_path}")

# %%
# # Define the file paths where the data was saved

# ctp_file_path = '/data/rong3/annie/completed_ctp_hilow_arrays/ctp_results.npz'

# hi_file_path = '/data/rong3/annie/completed_ctp_hilow_arrays/hi_results.npz'

# # Load the arrays from the .npz file
# ctp_data = np.load(ctp_file_path)

# hi_data = np.load(hi_file_path)

# # Extract the arrays from the loaded data
# ctp_results = ctp_data['ctp_results']

# hi_results = hi_data['hi_results']

# # contains lists of CTP for every month-day

# ctpdf = resultdf.groupby(['month', 'day'])['ctp'].agg(list).reset_index()

# ctpdf['ctpz']= ""

# for i in range(ctpdf.shape[0]):
    
#     # extracts all CTPs for the month-day 
    
#     x = np.array(ctpdf['ctp'][i])

#     x = x.reshape(-1, 1)

#     qt = QuantileTransformer(output_distribution='normal')
    
#     xqt = qt.fit_transform(x)
    
#     ctpdf['ctpz'][i] = xqt
    
# #output of xqt puts every value in a list, this removes the inner lists

# ctpdf['ctpz'] = ctpdf['ctpz'].apply(lambda x: [item for sublist in x for item in sublist])  

# ctp_raw = ctpdf.explode('ctp').drop('ctpz', axis=1)

# ctp_z = ctpdf.explode('ctpz').drop('ctp', axis=1)

# ctpz = ctp_z['ctpz']

# ctpdf = pd.concat([ctp_raw, ctpz], axis=1)

# resultdf = resultdf.reset_index()

# ctpdf = ctpdf.reset_index()

# resultdf = pd.merge(resultdf, ctpdf[['month','day', 'ctp', 'ctpz']], on=['month', 'day', 'ctp'], how='left')

# %%
# def cal_ctp_hi(temperature, dewpoint, pressure, altitude):
    
#     '''
#     INPUT:
#         temperature 
#         dewpoint
#         pressure
#         altitude 
#     Note: all input should have metpy.units but altitude
#     OUTPUT:
#         ctp  : Convective Triggering Potential
#         hi   : Humidity Index
#         moist_t : Moist adiabatic temperature profile from 1km to 3km AGL
#         cal_p   : Pressure profile from 1km to 3km AGL
#     '''
    
#     alt = altitude 
    
#     start_index = np.where(alt == alt[0] + 1000)[0][0]
    
#     end_index = np.where(alt == alt[0] + 3000)[0][0]
    
#     cal_p = pressure[start_index:end_index + 1]
        
#     cal_t = temperature[start_index:end_index + 1]
    
#     # to interpolate observed pressure profile to 2 hpa increments
    
#     p_level = np.arange(pressure[0].magnitude, pressure[-1].magnitude, -2) * units.hPa
    
#     # calculates a moist temperature profile against synthetic pressure levels (p_level)
    
#     # and using starting temperature and pressure as starting point
    
#     moist_temp = mpcalc.moist_lapse(
        
#         pressure=p_level, 
        
#         temperature=cal_t[0], 
        
#         reference_pressure=cal_p[0]
    
#     ).to(units.degC)
    
#     # cal_moist is segmented from moist_temp to 100 -> 300 hpa AGL
    
#     cal_moist = np.interp(
        
#         cal_p.magnitude[::-1],
        
#         p_level.magnitude[::-1],
        
#         moist_temp.magnitude[::-1]
    
#     )[::-1] * moist_temp.units
        
#     ctp = (Rd * (np.trapz(
        
#         (cal_moist.magnitude - cal_t.magnitude)[::-1], 
        
#         np.log(cal_p.magnitude)[::-1]
    
#     ) * units.degK)).to(units('J/kg'))
    
#     index0 = np.where(alt == alt[0] + 500)[0][0]
    
#     index1 = np.where(alt == alt[0] + 1500)[0][0]
    
#     hi = (temperature[index0] - dewpoint[index0] + 
          
#           temperature[index1] - dewpoint[index1])
    
#     print(temperature[index0] - dewpoint[index0],temperature[index1] - dewpoint[index1])
    
#     return ctp.magnitude, hi.magnitude

# %%
# print(ctp, "J/kg")

# plt.plot(cal_moist, cal_p, label='moist adiabat')

# plt.plot(cal_t, cal_p, color='red', label='observed t')

# plt.scatter(moist_temp, p_level, color='orange', s=1)

# plt.gca().invert_yaxis()

# plt.legend()

# plt.grid()

# plt.show()

# %%
# print(hi)

# plt.plot(temperature_test, altitude, label='temp')

# plt.plot(dewpoint_test, altitude, label='dp')

# plt.legend()

# plt.grid()

# plt.show()
